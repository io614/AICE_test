# %% [markdown]
# ## Objectives
#
# - Broadly speaking, there are 2 main motivations for carrying out data analyis or visualization
#     - **For understanding**: Using visualization techniques to understand the data for the purpose of further analysis/ modelling
#     - **For presentation**: Conveying findings from data to a broader audience (e.g. for policy making/ reporting/ business decisions)
#
# - This exercise will focus on the former, with the aim of improving the machine learning pipeline in part 3 of the assessment.
# - With that aim in mind, this EDA will be structured as follows:
#      1. **Setup**: Load required modules and import data (using script created in part 1 of the assessment)
#      2. **Glance**: Take a quick look at the raw data and take note of things that should be done in steps 3.
#      3. **Clean**: Deal with missing, anomalous, or "wrong" values observed in step 2
#      4. **Augment**: Create more features that may help the model learn from the data
#
# - The preprocessing stage of the machine learning pipeline will be adapated based on this

# %% [markdown]
# ## 1. Setup

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import mlp
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## options etc.

plt.rcParams['figure.figsize'] = [6, 4]
plt.rcParams['figure.dpi'] = 120

# %%
raw_df = mlp.setup.extract()

# %% [markdown]
# ## 2. Glance

# %% [markdown]
# #### Check missing values

# %%
raw_df.isna().sum()
# Out:
# date                      0
# hr                        0
# weather                   0
# temperature               0
# feels_like_temperature    0
# relative_humidity         0
# windspeed                 0
# psi                       0
# guest_scooter             0
# registered_scooter        0
# dtype: int64

# %% [markdown]
# Observations:
# - No missing values in this dataset.

# %% [markdown]
# #### Look at first and last entries, as well as other summary statistics

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18643 entries, 0 to 18642
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    18643 non-null  object
#  1   hr                      18643 non-null  int64
#  2   weather                 18643 non-null  object
#  3   temperature             18643 non-null  float64
#  4   feels_like_temperature  18643 non-null  float64
#  5   relative_humidity       18643 non-null  float64
#  6   windspeed               18643 non-null  float64
#  7   psi                     18643 non-null  int64
#  8   guest_scooter           18643 non-null  int64
#  9   registered_scooter      18643 non-null  int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 1.4+ MB

# %%
raw_df.head()
# Out:
#          date  hr weather  temperature  feels_like_temperature  \
# 0  2011-01-01   0   clear         66.7                    95.0
# 1  2011-01-01   1   clear         65.0                    93.2
# 2  2011-01-01   2    lear         65.0                    93.2
# 3  2011-01-01   3   clear         66.7                    95.0
# 4  2011-01-01   3   clear         66.7                    95.0
#
#    relative_humidity  windspeed  psi  guest_scooter  registered_scooter
# 0               81.0        0.0   50              7                  90
# 1               80.0        0.0    6             23                 224
# 2               80.0        0.0   25             14                 188
# 3               75.0        0.0   41              9                  70
# 4               75.0        0.0   41              9                  70

# %%
raw_df.tail()
# Out:
#              date  hr weather  temperature  feels_like_temperature  \
# 18638  2012-12-31  21   clear         68.4                    91.4
# 18639  2012-12-31  21   clear         68.4                    91.4
# 18640  2012-12-31  22   clear         68.4                    93.2
# 18641  2012-12-31  23   clear         68.4                    93.2
# 18642  2012-12-31  23   clear         68.4                    93.2
#
#        relative_humidity  windspeed  psi  guest_scooter  registered_scooter
# 18638               60.0       11.0   35             21                 585
# 18639               60.0       11.0   35             21                 585
# 18640               56.0        9.0    8             41                 337
# 18641               65.0        9.0   49             36                 258
# 18642               65.0        9.0   49             36                 258

# %%
raw_df.describe()
# Out:
#                  hr   temperature  feels_like_temperature  relative_humidity  \
# count  18643.000000  18643.000000            18643.000000       18643.000000
# mean      11.537145     88.433037              117.313608          62.733251
# std        6.924281     16.252200               20.364081          19.315897
# min        0.000000     48.100000               60.800000           0.000000
# 25%        6.000000     75.200000              100.400000          48.000000
# 50%       12.000000     88.700000              118.400000          63.000000
# 75%       18.000000    102.200000              134.600000          78.000000
# max       23.000000    131.000000              179.600000         100.000000
#
#           windspeed           psi  guest_scooter  registered_scooter
# count  18643.000000  18643.000000   18643.000000        18643.000000
# mean      12.741082     25.142198     106.388940         1074.471383
# std        8.217008     14.442978     147.151664         1055.916934
# min        0.000000      0.000000      -2.000000           -2.000000
# 25%        7.000000     13.000000      12.000000          240.000000
# 50%       13.000000     25.000000      50.000000          807.000000
# 75%       17.000000     38.000000     144.000000         1535.500000
# max       57.000000     50.000000    1099.000000         6203.000000

# %% [markdown]
# Observations:
#  - The maximum value of `temperature`, 131 degrees fahrenheit (55 degrees celsius), is suspiciously high. Need to check for anomalous points.
#  - The minimum value for `guest_scooter` and `registered_scooter` is negative. Obviously this doesn't make sense and will be investigated in part 3.

# %% [markdown]
# #### Check duplicates

# %%
duplicated_df = raw_df.loc[raw_df.duplicated(["date", "hr"], keep=False)]
duplicated_df
# Out:
#              date  hr weather  temperature  feels_like_temperature  \
# 3      2011-01-01   3   clear         66.7                    95.0
# 4      2011-01-01   3   clear         66.7                    95.0
# 7      2011-01-01   6   clear         65.0                    93.2
# 8      2011-01-01   6   clear         65.0                    93.2
# 9      2011-01-01   7   clear         63.3                    91.4
# ...           ...  ..     ...          ...                     ...
# 18621  2012-12-31   4   clear         58.2                    80.6
# 18638  2012-12-31  21   clear         68.4                    91.4
# 18639  2012-12-31  21   clear         68.4                    91.4
# 18641  2012-12-31  23   clear         68.4                    93.2
# 18642  2012-12-31  23   clear         68.4                    93.2
#
#        relative_humidity  windspeed  psi  guest_scooter  registered_scooter
# 3                   75.0        0.0   41              9                  70
# 4                   75.0        0.0   41              9                  70
# 7                   80.0        0.0   49              5                   0
# 8                   80.0        0.0   49              5                   0
# 9                   86.0        0.0   27              4                  12
# ...                  ...        ...  ...            ...                 ...
# 18621               69.0        7.0   47              0                  25
# 18638               60.0       11.0   35             21                 585
# 18639               60.0       11.0   35             21                 585
# 18641               65.0        9.0   49             36                 258
# 18642               65.0        9.0   49             36                 258
#
# [3152 rows x 10 columns]

# %% [markdown]
# Observations:
#
# - There are 3152 duplicate entries = 1576 duplicate pairs on the key pair `date`, `hour`. Need to drop those duplicates (keep first value of duplicate pair)

# %% [markdown]
# #### Check values of categorical variables

# %%
weather_counts_df = raw_df.groupby("weather").size().sort_index().rename("count").reset_index()
weather_counts_df
# Out:
#             weather  count
# 0             CLEAR    318
# 1            CLOUDY    126
# 2   LIGHT SNOW/RAIN     48
# 3              clar     99
# 4             clear  11627
# 5            cloudy   4613
# 6             cludy     32
# 7   heavy snow/rain      3
# 8              lear    233
# 9   light snow/rain   1455
# 10   liht snow/rain     15
# 11            loudy     74

# %% [markdown]
# Observations:
# - There are obviously some spelling errors. Let's correct this in part 3

# %% [markdown]
# #### Summarise and visualize correlations

# %%
# raw_df.pipe(sns.pairplot)

# %%
raw_df.corr().style.background_gradient(cmap="RdYlGn")
# Out:
# <style  type="text/css" >
#     #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row0_col0 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row0_col1 {
#             background-color:  #ef633f;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row0_col2 {
#             background-color:  #ed5f3c;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row0_col3 {
#             background-color:  #bd1726;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row0_col4 {
#             background-color:  #fdbd6d;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row0_col5 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row0_col6 {
#             background-color:  #fff8b4;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row0_col7 {
#             background-color:  #fdfebc;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row1_col0 {
#             background-color:  #fdb96a;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row1_col1 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row1_col2 {
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row1_col3 {
#             background-color:  #f57245;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row1_col4 {
#             background-color:  #f47044;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row1_col5 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row1_col6 {
#             background-color:  #daf08d;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row1_col7 {
#             background-color:  #fff7b2;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row2_col0 {
#             background-color:  #fdb768;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row2_col1 {
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row2_col2 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row2_col3 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row2_col4 {
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row2_col5 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row2_col6 {
#             background-color:  #dcf08f;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row2_col7 {
#             background-color:  #fff7b2;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row3_col0 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row3_col1 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row3_col2 {
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row3_col3 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row3_col4 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row3_col5 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row3_col6 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row3_col7 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row4_col0 {
#             background-color:  #fdb96a;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row4_col1 {
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row4_col2 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row4_col3 {
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row4_col4 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row4_col5 {
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row4_col6 {
#             background-color:  #fdb96a;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row4_col7 {
#             background-color:  #fba05b;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row5_col0 {
#             background-color:  #f57748;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row5_col1 {
#             background-color:  #c21c27;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row5_col2 {
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row5_col3 {
#             background-color:  #f99153;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row5_col4 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row5_col5 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row5_col6 {
#             background-color:  #f98e52;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row5_col7 {
#             background-color:  #f47044;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row6_col0 {
#             background-color:  #fff0a6;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row6_col1 {
#             background-color:  #fffcba;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row6_col2 {
#             background-color:  #fffab6;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row6_col3 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row6_col4 {
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row6_col5 {
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row6_col6 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row6_col7 {
#             background-color:  #d3ec87;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row7_col0 {
#             background-color:  #fbfdba;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row7_col1 {
#             background-color:  #fed27f;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row7_col2 {
#             background-color:  #fed07e;
#             color:  #000000;
#         }    #T_0d77ad1e_8700_11ea_b36b_00155ddf8211row7_col3 {
#             background-color:  #be1827;
#             color:  #f1f1f1;

# %% [markdown]
# Observations
#
# - From the correlation matrix, the strongest predictor-response relationship seems to involve `temperature`, `feels_like_temperature`, and `hr`
# - The predictors `temperature` and `feels_like_temperature` are highly correlated (collinear). If the focus were on significance testing and intepretibility, a data scientist might want to drop 1 of those variables or use dimensionality reduction techniques to combine them. The focus in this exercise, however, is building a prediction pipeline.
# - There is a curious "heart-shaped" relationship between `guest_scooter` and `total_scooter`
# - Looking at the correlation plot between `feels_like_temperature` and `temperature`, there is a horizontal line of points which deviate from the mostly linear relationship. Let's investigate this further in part 3.
# - Based on the histograms, there does not seem to be any obvious anomalous points in the `temperature` variable, as suspected above. Plotting a histogram confirms this:

# %%
fig, ax = plt.subplots(1,1)
raw_df.temperature.hist(ax=ax, bins=50)
ax.set_xlabel("Temperature (F)")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## 3. Clean

# %%
df = raw_df.copy()

# %% [markdown]
# #### Drop duplicate values

# %%
df = df.drop_duplicates(['date', 'hr'])

# %% [markdown]
# #### Correct typos in `weather`

# %%
weather_counts_df
# Out:
#             weather  count
# 0             CLEAR    318
# 1            CLOUDY    126
# 2   LIGHT SNOW/RAIN     48
# 3              clar     99
# 4             clear  11627
# 5            cloudy   4613
# 6             cludy     32
# 7   heavy snow/rain      3
# 8              lear    233
# 9   light snow/rain   1455
# 10   liht snow/rain     15
# 11            loudy     74

# %%
## regex search strings to replace with values

pairs_list = [(r"\w*l\w+r$", "clear"),
              (r"\w*l\w+dy$", "cloudy"),
              (r"\w*l\w+t snow.*", "light snow/rain")]

# %%
to_replace, value = list(zip(*pairs_list))


## make function to create a weather_corrected column

def correct_weather(df):
    return df.assign(weather_corrected = lambda x: x.weather.str.lower().\
                                                      replace(to_replace=to_replace, value=value, regex=True))

## check if function works

weather_counts_df.pipe(correct_weather)
# Out:
#             weather  count weather_corrected
# 0             CLEAR    318             clear
# 1            CLOUDY    126            cloudy
# 2   LIGHT SNOW/RAIN     48   light snow/rain
# 3              clar     99             clear
# 4             clear  11627             clear
# 5            cloudy   4613            cloudy
# 6             cludy     32            cloudy
# 7   heavy snow/rain      3   heavy snow/rain
# 8              lear    233             clear
# 9   light snow/rain   1455   light snow/rain
# 10   liht snow/rain     15   light snow/rain
# 11            loudy     74            cloudy

# %%
# Ascertain that the weather categories are indeed corrected :

df = df.pipe(correct_weather)

df.groupby("weather_corrected").size()
# Out:
# weather_corrected
# clear              11195
# cloudy              4443
# heavy snow/rain        3
# light snow/rain     1390
# dtype: int64

# %% [markdown]
# #### Negative scooter counts

# %%
negative_mask = (df.guest_scooter < 0) | (df.registered_scooter < 0)

df.loc[negative_mask]
# Out:
#              date  hr weather  temperature  feels_like_temperature  \
# 6      2011-01-01   5  cloudy         66.7                    91.4
# 33     2011-01-02   7  cloudy         80.2                   109.4
# 48     2011-01-02  22   clear         66.7                    86.0
# 52     2011-01-03   4   clear         59.9                    77.0
# 53     2011-01-03   5   clear         59.9                    77.0
# ...           ...  ..     ...          ...                     ...
# 18565  2012-12-29   4  cloudy         66.7                    89.6
# 18587  2012-12-29  23  cloudy         68.4                    89.6
# 18589  2012-12-30   2  cloudy         68.4                    89.6
# 18592  2012-12-30   4  cloudy         68.4                    91.4
# 18593  2012-12-30   5  cloudy         68.4                    87.8
#
#        relative_humidity  windspeed  psi  guest_scooter  registered_scooter  \
# 6                   75.0        6.0   35             -1                  11
# 33                  76.0       13.0   42             -2                  10
# 48                  44.0       20.0   36             -2                  61
# 52                  47.0       26.0   27             -2                  10
# 53                  47.0       19.0   32             -2                  21
# ...                  ...        ...  ...            ...                 ...
# 18565               75.0        6.0    5             -1                  20
# 18587               60.0        0.0   41             -2                 228
# 18589               56.0       19.0   48             -2                 137
# 18592               56.0       15.0   33             -2                  53
# 18593               48.0       20.0   38             -2                  19
#
#       weather_corrected
# 6                cloudy
# 33               cloudy
# 48                clear
# 52                clear
# 53                clear
# ...                 ...
# 18565            cloudy
# 18587            cloudy
# 18589            cloudy
# 18592            cloudy
# 18593            cloudy
#
# [602 rows x 11 columns]

# %% [markdown]
# These entries may represent data collection errors. Let's drop these entries as the errors are found in the response variables, which may lead the machine learning algorithm to learn "wrongly".

# %%
df = df.loc[~negative_mask]

# %% [markdown]
# #### Potential temperature measurement error

# %%
fig, ax= plt.subplots(1,1)

df.plot.scatter(x='temperature', y='feels_like_temperature', ax=ax)
ax.grid()

# %% [markdown]
# - Further inspection of the correlation plot indicates that there are some quirks at `feels_like_temperature` = 89.6 (horizontal line on plot)
# - This may be indicative of some kind of systematic error
# - Since there are only 23 such points, dropping them probably will not affect the final outcome
# - To identify the points to drop we compute the absolute difference between the `feels_like_temperature` and `temperature` z-scores

# %%
def get_z_score(df, col):
    df_new = df.copy()
    df_new[col+"_z_score"] = (df[col] - df[col].mean())/ df[col].std()
    return df_new

df = df.pipe(get_z_score, "temperature").\
     pipe(get_z_score, "feels_like_temperature").\
     assign(z_score_diff_abs = lambda x: (x.temperature_z_score - x.feels_like_temperature_z_score).abs())

# %%
df.z_score_diff_abs.plot.box()

# %% [markdown]
# Inspecting the boxplot above allows us to discern a group of outliers with `z_score_diff_abs` > 1.5 . Hence, we set our threshold at this default. This threshold can be modified in the `config.yaml` file.

# %%
z_threshold = 1.5

# %%
df['above_threshold'] = df['z_score_diff_abs'] > z_threshold

# %%
fig, ax = plt.subplots(1,1)

df.query("above_threshold").plot.scatter(x='temperature', y='feels_like_temperature', label="above_threshold", ax=ax, color="red")
df.query("not above_threshold").plot.scatter(x='temperature', y='feels_like_temperature', label="below_threshold", ax=ax, color="green")

# %% [markdown]
# As seen above, this method helps to isolate the anomalous points. We drop the entries above the threshold.

# %%
df = df.query("not above_threshold")

# %% [markdown]
# ### 4. Create features

# %% [markdown]
# #### Create `total_scooter` column

# %% [markdown]
# This is the variable to be predicted

# %%
df["total_scooter"] = df["guest_scooter"] + df["registered_scooter"]

# %% [markdown]
# #### Encode weather as ordinal

# %% [markdown]
# There seems to be a natural ordering to the "weather" variable, ranging from clear (least severe) to heavy rain/snow (most severe). Let's encode it as an ordinal. In the full pipeline, the user can configure the values in `config.yaml`.

# %%
weather_ord_encoding= {'clear': 0,
                       'cloudy': 1,
                       'light snow/rain': 2,
                       'heavy snow/rain': 3}

# %%
weather, ordinal = list(zip(*weather_ord_encoding.items()))

lookup_weather = pd.Series(index=weather,
                           data=ordinal,
                           name="weather_encoded")

# %%
df = df.merge(lookup_weather, left_on="weather_corrected", right_index=True).sort_values(["date", "hr"])

# %% [markdown]
# #### Create `datetime` column

# %%
## Make datetime column

df['datetime'] = pd.to_datetime(df.date + ' ' + df.hr.astype(str) + ":00")

# %% [markdown]
# #### Create date and time related features

# %% [markdown]
# Riding scooters is a human activity which is likely to be influenced by factors such as the type of day (business day or not), month of the year, and daylight hours. These may seem obvious to us, but is hard for the machine learning algorithm to infer purely from the data procided. Hence, we need to give it a bit of "help" by creating some extra features.

# %% [markdown]
# ##### Weekends

# %% [markdown]
# Here, we create indicator variables for weekends, based on the day of the week. If we had more specific information about the location of this city, we could combine it with regional holidays to create a "business days" variable.

# %%
df['is_weekend'] = df.datetime.dt.dayofweek.isin([5,6])

# %%
fig, ax = plt.subplots(1,1)

df[lambda x: x.is_weekend==False].plot.scatter(x="guest_scooter", y="registered_scooter", ax=ax, c="red", label="weekday")
df[lambda x: x.is_weekend==True].plot.scatter(x="guest_scooter", y="registered_scooter", ax=ax, c="green", label="weekend")

# %% [markdown]
# - Although this doesn't help the goal of predicting `total_scooter`, creating this variable helps explain the "heart-shaped" correlation between `registered_scooter` and `guest_scooter` – the correlation between those variables depends on the type of day. One might conclude that rental e-scooters are used more on weekend.

# %% [markdown]
# ##### Month of year

# %%
df['month'] = df.datetime.dt.month

# %%
sns.boxplot(x='month', y='total_scooter', data= df)

# %% [markdown]
# More scooter journeys are made in the warmer months. However, this could be attributed to the temperature variables as well.

# %% [markdown]
# ##### Time of day

# %%
df.groupby(['month', 'hr'])['registered_scooter'].mean().unstack().T.style.background_gradient(cmap="RdYlGn")
# Out:
# <style  type="text/css" >
#     #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col0 {
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col1 {
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col2 {
#             background-color:  #ce2827;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col3 {
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col4 {
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col5 {
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col6 {
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col7 {
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col8 {
#             background-color:  #d93429;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col9 {
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col10 {
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row0_col11 {
#             background-color:  #da362a;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col0 {
#             background-color:  #c41e27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col1 {
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col2 {
#             background-color:  #bd1726;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col3 {
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col4 {
#             background-color:  #c21c27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col5 {
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col6 {
#             background-color:  #c82227;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col7 {
#             background-color:  #be1827;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col8 {
#             background-color:  #c21c27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col9 {
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col10 {
#             background-color:  #c21c27;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row1_col11 {
#             background-color:  #ca2427;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col0 {
#             background-color:  #be1827;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col1 {
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col2 {
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col3 {
#             background-color:  #b50f26;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col4 {
#             background-color:  #b50f26;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col5 {
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col6 {
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col7 {
#             background-color:  #b50f26;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col8 {
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col9 {
#             background-color:  #b50f26;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col10 {
#             background-color:  #b50f26;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row2_col11 {
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col0 {
#             background-color:  #b10b26;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col1 {
#             background-color:  #ad0826;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col2 {
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col3 {
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col4 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col5 {
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col6 {
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col7 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col8 {
#             background-color:  #ad0826;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col9 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col10 {
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row3_col11 {
#             background-color:  #ab0626;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col0 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col1 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col2 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col3 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col4 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col5 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col6 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col7 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col8 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col9 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col10 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_0ee1b6f4_8700_11ea_b36b_00155ddf8211row4_col11 {
#             background-color:  #a50026;
#             color:  #f

# %% [markdown]
# From the heat map above, is is clear that we need to create a `is_rush_hour` column to explain the peaks at 8, 17, and 18 hours. These can be configured in the `config.yaml` file

# %%
rush_hours = [8, 17, 18]

# %%
df['is_rush_hour'] = df.hr.isin(rush_hours)

# %% [markdown]
# #### Encode cyclic variables as 2-valued cartesian coordinate

# %% [markdown]
# We do not want the machine learning algorithm to treat hours "0" and "23" as values from opposite ends of the spectrum when they are in fact neighours. Hence we encode

# %%
def encode_cyclic(df, var, period):
    df_new = df.copy()
    df_new[ var + "_y"] = np.sin(2*np.pi*df[var]/period)
    df_new[ var + "_x"] = np.cos(2*np.pi*df[var]/period)
    
    return df_new

# %%
df = df.pipe(encode_cyclic, "hr", 24)\
       .pipe(encode_cyclic, "month", 12)

# %% [markdown]
# As we can see in the plots below, the `hr` and `month` coordinates are now encoded in a way that reflects their cyclic nature

# %%
df.plot.scatter(x="month_x", y="month_y", c=df.month, cmap="viridis")
plt.gca().set_aspect('equal', adjustable='box')

# %%
df.plot.scatter(x="hr_x", y="hr_y", c=df.hr, cmap="viridis")
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# #### Drop unwanted columns

# %%
df_final = df.drop(columns = ["hr",
                               "date",
                               "weather",
                               "guest_scooter",
                               "registered_scooter",
                               "weather_corrected",
                               "datetime",
                               "month",
                               "temperature_z_score",
                               "feels_like_temperature_z_score",
                               "z_score_diff_abs",
                               "above_threshold"])

# %%
df_final
# Out:
#        temperature  feels_like_temperature  relative_humidity  windspeed  psi  \
# 0             66.7                    95.0               81.0        0.0   50
# 1             65.0                    93.2               80.0        0.0    6
# 2             65.0                    93.2               80.0        0.0   25
# 3             66.7                    95.0               75.0        0.0   41
# 5             66.7                    95.0               75.0        0.0    9
# ...            ...                     ...                ...        ...  ...
# 18636         68.4                    91.4               60.0       11.0   15
# 18637         68.4                    91.4               60.0       11.0   25
# 18638         68.4                    91.4               60.0       11.0   35
# 18640         68.4                    93.2               56.0        9.0    8
# 18641         68.4                    93.2               65.0        9.0   49
#
#        total_scooter  weather_encoded  is_weekend  is_rush_hour      hr_y  \
# 0                 97                0        True         False  0.000000
# 1                247                0        True         False  0.258819
# 2                202                0        True         False  0.500000
# 3                 79                0        True         False  0.707107
# 5                 13                0        True         False  0.866025
# ...              ...              ...         ...           ...       ...
# 18636            794                1       False         False -0.965926
# 18637            598                1       False         False -0.866025
# 18638            606                0       False         False -0.707107
# 18640            378                0       False         False -0.500000
# 18641            294                0       False         False -0.258819
#
#            hr_x       month_y   month_x
# 0      1.000000  5.000000e-01  0.866025
# 1      0.965926  5.000000e-01  0.866025
# 2      0.866025  5.000000e-01  0.866025
# 3      0.707107  5.000000e-01  0.866025
# 5      0.500000  5.000000e-01  0.866025
# ...         ...           ...       ...
# 18636  0.258819 -2.449294e-16  1.000000
# 18637  0.500000 -2.449294e-16  1.000000
# 18638  0.707107 -2.449294e-16  1.000000
# 18640  0.866025 -2.449294e-16  1.000000
# 18641  0.965926 -2.449294e-16  1.000000
#
# [16406 rows x 13 columns]

# %%
df_final.corr().style.background_gradient(cmap="RdYlGn")
# Out:
# <style  type="text/css" >
#     #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col0 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col1 {
#             background-color:  #016a38;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col2 {
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col3 {
#             background-color:  #f47044;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col4 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col5 {
#             background-color:  #f2faae;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col6 {
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col7 {
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col8 {
#             background-color:  #ee613e;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col9 {
#             background-color:  #e54e35;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col10 {
#             background-color:  #ef633f;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col11 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row0_col12 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col0 {
#             background-color:  #016a38;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col1 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col2 {
#             background-color:  #f16640;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col3 {
#             background-color:  #ed5f3c;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col4 {
#             background-color:  #a90426;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col5 {
#             background-color:  #f4fab0;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col6 {
#             background-color:  #b10b26;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col7 {
#             background-color:  #b50f26;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col8 {
#             background-color:  #ee613e;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col9 {
#             background-color:  #e65036;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col10 {
#             background-color:  #f26841;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col11 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row1_col12 {
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col0 {
#             background-color:  #fed884;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col1 {
#             background-color:  #feda86;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col2 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col3 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col4 {
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col5 {
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col6 {
#             background-color:  #fffbb8;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col7 {
#             background-color:  #c82227;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col8 {
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col9 {
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col10 {
#             background-color:  #fff6b0;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col11 {
#             background-color:  #f46d43;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row2_col12 {
#             background-color:  #feeb9d;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col0 {
#             background-color:  #fee28f;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col1 {
#             background-color:  #fed884;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col2 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col3 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col4 {
#             background-color:  #a70226;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col5 {
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col6 {
#             background-color:  #e24731;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col7 {
#             background-color:  #cc2627;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col8 {
#             background-color:  #f57547;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col9 {
#             background-color:  #e44c34;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col10 {
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col11 {
#             background-color:  #fee695;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row3_col12 {
#             background-color:  #feeb9d;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row4_col0 {
#             background-color:  #fee797;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row4_col1 {
#             background-color:  #fee695;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row4_col2 {
#             background-color:  #f67c4a;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row4_col3 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row4_col4 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row4_col5 {
#             background-color:  #fa9857;
#             color:  #000000;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row4_col6 {
#             background-color:  #d93429;
#             color:  #f1f1f1;
#         }    #T_3d98a994_8700_11ea_b36b_00155ddf8211row4_col7 {
#             background-color:  #d02927;
#             color:
